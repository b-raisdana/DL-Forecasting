# %%
import pandas as pd
from helper.data_preparation import single_timeframe
from helper.helper import date_range_to_string
from Model.Data.atr import read_multi_timeframe_ohlcva
# Out:
# DEBUG@09-20.18:06:52:...Starting

# %%
mt_ohlcva = read_multi_timeframe_ohlcva(
    date_range_to_string(start=pd.to_datetime('02-07-24'), end=pd.to_datetime('08-07-24')))
mt_ohlcva
# Out:
# DEBUG@09-20.18:06:58:core_generate_multi_timeframe_ohlcva(24-02-07.00-00T24-02-07.23-59) started
# DEBUG@09-20.18:06:58:generate_multi_timeframe_ohlcv(24-02-06.23-44T17-12-31.23-59) started
# INFO@09-20.18:06:58:Error in generate_multi_timeframe_ohlcv(24-02-06.23-44T17-12-31.23-59): No objects to concatenate
# INFO@09-20.18:06:58:Error in core_generate_multi_timeframe_ohlcva(24-02-07.00-00T24-02-07.23-59): No objects to concatenate
#   File "C:\Code\dl-forcasting\src\helper\data_preparation.py", line 111, in read_file
#     generator(date_range_str, **generator_params)
#   File "C:\Code\dl-forcasting\src\helper\helper.py", line 103, in _measure_time
#     log(f"Error in {func.__name__}({function_parameters}): {str(e)}", stack_trace=True)
#   File "C:\Code\dl-forcasting\src\helper\data_preparation.py", line 111, in read_file
#     generator(date_range_str, **generator_params)
#   File "C:\Code\dl-forcasting\src\helper\helper.py", line 103, in _measure_time
#     log(f"Error in {func.__name__}({function_parameters}): {str(e)}", stack_trace=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 mt_ohlcva = read_multi_timeframe_ohlcva(
#       2     date_range_to_string(start=pd.to_datetime('02-07-24'), end=pd.to_datetime('08-07-24')))
#       3 mt_ohlcva
#
# File C:\Code\dl-forcasting\src\Model\TechnicalAnalysis\atr.py:89, in read_multi_timeframe_ohlcva(date_range_str)
#      87 if date_range_str is None:
#      88     date_range_str = config.processing_date_range
# ---> 89 result = read_file(date_range_str, 'multi_timeframe_ohlcva', generate_multi_timeframe_ohlcva,
#      90                    MultiTimeframeOHLCVA)
#      91 cache_times(result)
#      92 return result
#
# File C:\Code\dl-forcasting\src\helper\data_preparation.py:113, in read_file(date_range_str, data_frame_type, generator, caster_model, skip_rows, n_rows, file_path, zero_size_allowed, generator_params)
#     111     generator(date_range_str, **generator_params)
#     112 except Exception as e:
# --> 113     raise e
#     114 df = read_with_timeframe(data_frame_type, date_range_str, file_path, n_rows, skip_rows)
#     115 df = cast_and_validate(df, caster_model, zero_size_allowed=zero_size_allowed)
#
# File C:\Code\dl-forcasting\src\helper\data_preparation.py:111, in read_file(date_range_str, data_frame_type, generator, caster_model, skip_rows, n_rows, file_path, zero_size_allowed, generator_params)
#     109 if df is None or not cast_and_validate(df, caster_model, return_bool=True, zero_size_allowed=zero_size_allowed):
#     110     try:
# --> 111         generator(date_range_str, **generator_params)
#     112     except Exception as e:
#     113         raise e
#
# File C:\Code\dl-forcasting\src\Model\TechnicalAnalysis\atr.py:73, in generate_multi_timeframe_ohlcva(date_range_str, file_path)
#      69 daily_dataframes = []
#      71 while current_day.date() <= end.date():
#      72     # For each day, get the data and append to daily_dataframes list
# ---> 73     daily_dataframes.append(read_daily_multi_timeframe_ohlcva(current_day))
#      74     current_day += timedelta(days=1)
#      76 # Concatenate the daily data
#
# File C:\Code\dl-forcasting\src\Model\TechnicalAnalysis\atr.py:143, in read_daily_multi_timeframe_ohlcva(day, timezone)
#     141     return empty_df(MultiTimeframeOHLCVA)
#     142 # Fetch the data for the given day using the old function
# --> 143 return core_read_multi_timeframe_ohlcva(day_date_range_str)
#
# File C:\Code\dl-forcasting\src\Model\TechnicalAnalysis\atr.py:128, in core_read_multi_timeframe_ohlcva(date_range_str)
#     126 def core_read_multi_timeframe_ohlcva(date_range_str: str = None) \
#     127         -> pt.DataFrame[MultiTimeframeOHLCVA]:
# --> 128     result = read_file(date_range_str, 'multi_timeframe_ohlcva', core_generate_multi_timeframe_ohlcva,
#     129                        MultiTimeframeOHLCVA)
#     130     cache_times(result)
#     131     return result
#
# File C:\Code\dl-forcasting\src\helper\data_preparation.py:113, in read_file(date_range_str, data_frame_type, generator, caster_model, skip_rows, n_rows, file_path, zero_size_allowed, generator_params)
#     111     generator(date_range_str, **generator_params)
#     112 except Exception as e:
# --> 113     raise e
#     114 df = read_with_timeframe(data_frame_type, date_range_str, file_path, n_rows, skip_rows)
#     115 df = cast_and_validate(df, caster_model, zero_size_allowed=zero_size_allowed)
#
# File C:\Code\dl-forcasting\src\helper\data_preparation.py:111, in read_file(date_range_str, data_frame_type, generator, caster_model, skip_rows, n_rows, file_path, zero_size_allowed, generator_params)
#     109 if df is None or not cast_and_validate(df, caster_model, return_bool=True, zero_size_allowed=zero_size_allowed):
#     110     try:
# --> 111         generator(date_range_str, **generator_params)
#     112     except Exception as e:
#     113         raise e
#
# File C:\Code\dl-forcasting\src\helper\helper.py:97, in measure_time.<locals>._measure_time(*args, **kwargs)
#      94 log_d(f"{func.__name__}({function_parameters}) started", stack_trace=False)
#      96 try:
# ---> 97     result = func(*args, **kwargs)
#      98 except OSError as e:
#      99     log_e(f"Current directory is {os.path.abspath(os.path.curdir)}", stack_trace=False)
#
# File C:\Code\dl-forcasting\src\Model\TechnicalAnalysis\atr.py:110, in core_generate_multi_timeframe_ohlcva(date_range_str, file_path)
#     104     pass
#     105 expanded_date_range = \
#     106     expand_date_range(date_range_str,
#     107                       time_delta=((config.atr_timeperiod + 2) * pd.to_timedelta(timeframe) *
#     108                                   config.atr_safe_start_expand_multipliers),
#     109                       mode='start')
# --> 110 expanded_date_multi_timeframe_ohlcv = read_multi_timeframe_ohlcv(expanded_date_range)
#     111 timeframe_ohlcv = single_timeframe(expanded_date_multi_timeframe_ohlcv, timeframe)
#     112 timeframe_ohlcva = insert_atr(timeframe_ohlcv)
#
# File C:\Code\dl-forcasting\src\Model\Data\ohlcv.py:91, in read_multi_timeframe_ohlcv(date_range_str)
#      89 if date_range_str is None:
#      90     date_range_str = config.processing_date_range
# ---> 91 result = read_file(date_range_str, 'multi_timeframe_ohlcv', generate_multi_timeframe_ohlcv,
#      92                    MultiTimeframeOHLCV)
#      93 cache_times(result)
#      94 return result
#
# File C:\Code\dl-forcasting\src\helper\data_preparation.py:113, in read_file(date_range_str, data_frame_type, generator, caster_model, skip_rows, n_rows, file_path, zero_size_allowed, generator_params)
#     111     generator(date_range_str, **generator_params)
#     112 except Exception as e:
# --> 113     raise e
#     114 df = read_with_timeframe(data_frame_type, date_range_str, file_path, n_rows, skip_rows)
#     115 df = cast_and_validate(df, caster_model, zero_size_allowed=zero_size_allowed)
#
# File C:\Code\dl-forcasting\src\helper\data_preparation.py:111, in read_file(date_range_str, data_frame_type, generator, caster_model, skip_rows, n_rows, file_path, zero_size_allowed, generator_params)
#     109 if df is None or not cast_and_validate(df, caster_model, return_bool=True, zero_size_allowed=zero_size_allowed):
#     110     try:
# --> 111         generator(date_range_str, **generator_params)
#     112     except Exception as e:
#     113         raise e
#
# File C:\Code\dl-forcasting\src\helper\helper.py:97, in measure_time.<locals>._measure_time(*args, **kwargs)
#      94 log_d(f"{func.__name__}({function_parameters}) started", stack_trace=False)
#      96 try:
# ---> 97     result = func(*args, **kwargs)
#      98 except OSError as e:
#      99     log_e(f"Current directory is {os.path.abspath(os.path.curdir)}", stack_trace=False)
#
# File C:\Code\dl-forcasting\src\Model\Data\ohlcv.py:122, in generate_multi_timeframe_ohlcv(date_range_str, file_path)
#     119     current_day += timedelta(days=1)
#     121 # Concatenate the daily data
# --> 122 df = pd.concat(daily_dataframes)
#     123 df = df.sort_index(level='date')
#     124 df = trim_to_date_range(date_range_str, df)
#
# File C:\Code\dl-forcasting\venv\Lib\site-packages\pandas\core\reshape\concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# File C:\Code\dl-forcasting\venv\Lib\site-packages\pandas\core\reshape\concat.py:445, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     442 self.verify_integrity = verify_integrity
#     443 self.copy = copy
# --> 445 objs, keys = self._clean_keys_and_objs(objs, keys)
#     447 # figure out what our result ndim is going to be
#     448 ndims = self._get_ndims(objs)
#
# File C:\Code\dl-forcasting\venv\Lib\site-packages\pandas\core\reshape\concat.py:507, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     504     objs_list = list(objs)
#     506 if len(objs_list) == 0:
# --> 507     raise ValueError("No objects to concatenate")
#     509 if keys is None:
#     510     objs_list = list(com.not_none(*objs_list))
#
# ValueError: No objects to concatenate

# %%
org_columns = mt_ohlcv.columns

for timeframe in mt_ohlcv.index.get_level_values(level='timeframe').unique():
    tf_indexes = single_timeframe(mt_ohlcv, timeframe, index_only=True)
    ohlcv = single_timeframe(mt_ohlcv, timeframe)
    shifted_ohlcv = ohlcv.shift(1)
    # ohlcv = ohlcv.merge(shifted_ohlcv, how='left', left_index=True, right_index=True, suffixes=('', '_shifted'))
    concatenated_df = pd.concat([ohlcv, shifted_ohlcv], axis=1, join='outer', keys=['current', 'shifted'], names=['data_type'])
    
    # Optionally rename the columns of the shifted dataframe
    concatenated_df.columns = [f'{col}_shifted' if col in shifted_ohlcv.columns else col for col in concatenated_df.columns]
    mt_ohlcv.loc[tf_indexes] = concatenated_df
    nop = 1
    
# for col in org_columns:
#     mt_ohlcv.loc[tf_indexes,f'd_{col}'] = ohlcv[col] - ohlcv[f'{col}_shifted']
#     mt_ohlcv.loc[tf_indexes,f'r_{col}'] = np.log(ohlcv[col] / ohlcv[f'{col}_shifted'])
#     nop = 1
# mt_ohlcv

# %%
mt_ohlcva[,f'd_{col}'] = ohlcv[col] - ohlcv[f'{col}_shifted']

# %%
mt_ohlcv[f'th_d_{col}']
# Out:
#                               open    close     high      low        volume  \
# date
# 2024-02-12 00:00:00+00:00  48297.7  49923.9  50336.8  47716.8  10053.971028
# 2024-02-19 00:00:00+00:00  52133.0  51777.1  52487.3  51681.1   3613.178749
# 2024-02-26 00:00:00+00:00  51727.9  54472.1  54908.2  50901.9   7157.665916
# 2024-03-04 00:00:00+00:00  63112.9  68248.5  68510.6  62301.6  12031.235530
# 2024-03-11 00:00:00+00:00  68953.9  72085.5  72800.0  67092.3   8929.138139
# 2024-03-18 00:00:00+00:00  68395.9  67615.9  68966.0  66560.9   7931.394328
# 2024-03-25 00:00:00+00:00  67206.7  69868.9  71145.3  66383.3   8453.777943
# 2024-04-01 00:00:00+00:00  71257.7  69653.0  71274.8  68039.1   3362.179645
# 2024-04-08 00:00:00+00:00  69350.0  71626.4  72780.5  69049.1   3092.769918
