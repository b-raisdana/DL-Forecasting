# %% [markdown]
# # Labeled Future Window — Dataset Generation Visual Review
#
# Offline visual review of Tier-1_000 `input3_outcome1` samples. Shows the **actual 5min candlesticks** around each NOW anchor, shades the **240-minute future window**, and overlays the computed **action / mfe / rer labels** on it.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
while ROOT.name != "DL-Forecasting" and ROOT.parent != ROOT:
    ROOT = ROOT.parent
APP = ROOT / "app"
if str(APP) not in sys.path:
    sys.path.insert(0, str(APP))

from presentation.dataset_generation.labeled_future_window_review import (
    SYMBOLS,
    build_review_samples,
    plot_labeled_branch_sample,
    plot_labeled_future_window,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 11
#       7 APP = ROOT / "app"
#       8 if str(APP) not in sys.path:
#       9     sys.path.insert(0, str(APP))
#      10
# ---> 11 from presentation.dataset_generation.labeled_future_window_review import (
#      12     SYMBOLS,
#      13     build_review_samples,
#      14     plot_labeled_branch_sample,
#
# File ~/code/DL-Forecasting/app/presentation/dataset_generation/labeled_future_window_review.py:9
#       7 import numpy as np
#       8 import pandas as pd
# ----> 9 from application.model_implementations.tier1_000.datafeeder_input3_outcome1 import (
#      10     DatasetBundle,
#      11     build_dataset,
#      12 )
#      13 from application.model_implementations.tier1_000.model import (
#      14     BRANCH_TIMEFRAMES,
#      15     CANDLE_FEATURE_COLUMNS,
#      16 )
#      17 from config import app_config
#
# File ~/code/DL-Forecasting/app/application/model_implementations/tier1_000/datafeeder_input3_outcome1.py:38
#      36 import pandas as pd
#      37 import tensorflow as tf
# ---> 38 from application.dataset_generation.extremum_features import (
#      39     BranchExtremum,
#      40     align_source_atr,
#      41     build_branch_extremum,
#      42     compute_extremum_weight,
#      43     compute_higher_extremum_distance,
#      44 )
#      45 from application.dataset_generation.mfe_mae_om_labels import add_mfe_mae_om_labels
#      46 from application.dataset_generation.relative_candle import add_relative_candle_columns
#
# File ~/code/DL-Forecasting/app/application/dataset_generation/extremum_features.py:20
#      18 import numpy.typing as npt
#      19 import pandas as pd
# ---> 20 from domain.price_action.CausalExtremum import compute_true_extremum, floor_to_tf_ladder
#      21 from domain.schemas.price_action.CausalExtremum import CausalExtremumOHLC
#      22 from domain.schemas.price_action.extremum_features import BranchExtremumOHLC
#
# File ~/code/DL-Forecasting/app/domain/price_action/CausalExtremum.py:43
#      41 import pandas as pd
#      42 from domain.schemas.price_action.CausalExtremum import CausalExtremumOHLC, CausalExtremumResult
# ---> 43 from helper.pandera import pandera_validate
#      44 from pandera import typing as pt
#      46 # This codebase's lowercase-h timeframe convention (differs from the spec jsonc's "1H"/"4H", same
#      47 # meaning). 1M/4M/1Y have no native cached series anywhere in this codebase (app_config.timeframes
#      48 # stops at 1W) — they exist only as ladder rungs that a coarser branch's (1W's) own reach can validly
#      49 # extend into, per the input spec's plus2TF/plus3TF definitions.
#
# File ~/code/DL-Forecasting/app/helper/pandera.py:27
#      25 import pandas as pd
#      26 import pandera.pandas as pa
# ---> 27 from config import app_config
#      28 from helper.logging.do_log.log_it import log_w
#      29 from pandera import typing as pt
#
# File ~/code/DL-Forecasting/app/config/__init__.py:1
# ----> 1 from .Config import Config, app_config
#       3 __all__ = ["Config", "app_config"]
#
# File ~/code/DL-Forecasting/app/config/Config.py:37
#      11 # class CandleSize(Enum):
#      12 # @dataclass
#      13 # class MinMax:
#    (...)     30 # PEAK = "peak"
#      31 # VALLEY = "valley"
#      34 _ROOT_PATH = Path(__file__).resolve().parent.parent.parent
# ---> 37 class Config(BaseSettings):  # type: ignore[explicit-any]
#      38     """Runtime settings. Any field can be overridden via a `DLF_<FIELD_NAME>` env var
#      39     (or a `.env` file), validated against its declared type/bounds on load and on
#      40     every later `app_config.<field> = ...` assignment."""
#      42     model_config = SettingsConfigDict(
#      43         env_prefix="DLF_",
#      44         env_file=".env",
#      45         extra="ignore",
#      46         validate_assignment=True,
#      47     )
#
# File ~/code/DL-Forecasting/app/config/Config.py:163, in Config()
#     159 pivot_number_of_active_hits: int = Field(default=2, gt=0)
#     161 check_assertions: bool = True
# --> 163 environment: Literal["development", "production"] = "development"
#     165 id: str = ""
#     166 GLOBAL_CACHE: dict[str, object] = Field(default_factory=dict)
#
# NameError: name 'Literal' is not defined

# %% [markdown]
# ## Candlestick review — future window with labels
#
# Each figure shows 5min candles around a NOW anchor. Candles after NOW belong to the label horizon. The selected extremum and its MFE / RER are annotated.

# %%
for symbol in SYMBOLS:
    try:
        samples = build_review_samples(symbol, sample_count=5)
    except Exception as exc:
        print(f"{symbol}: skipped ({exc})")
        continue
    for idx, sample in enumerate(samples, start=1):
        fig = plot_labeled_future_window(sample, title=f"{symbol} future window sample {idx}")
        fig.show()

# %% [markdown]
# ## Branch feature windows (reference)
#
# One row per branch timeframe, x=0 at NOW. Labels are summarized in each title.

# %%
for symbol in SYMBOLS:
    try:
        samples = build_review_samples(symbol, sample_count=5)
    except Exception as exc:
        print(f"{symbol}: skipped ({exc})")
        continue
    for idx, sample in enumerate(samples, start=1):
        fig = plot_labeled_branch_sample(sample, title=f"{symbol} branch sample {idx}")
        fig.show()
