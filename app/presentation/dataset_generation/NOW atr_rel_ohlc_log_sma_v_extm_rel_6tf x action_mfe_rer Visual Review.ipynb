# %% [markdown]
# # NOW atr_rel_ohlc_log_sma_v_extm_rel_6tf x action_mfe_rer Visual Review
#
# Offline visual review notebook for already-fetched cached data. It does not call broker/exchange fetchers.
#
# Tests input variation 3 of [`atr_rel_ohlc_log_sma_v_extm_rel_6tf(handmade).input.jsonc`](<../../../docs/ML_Forecasting_System_Design/designsets/input-data-feature/Tier-1_000.atr_rel_ohlc_log_sma_v_extm_rel_6tf(handmade).input.jsonc>) crossed with outcome set 1 of [`action_mfe_rer(handmade).outcome.jsonc`](<../../../docs/ML_Forecasting_System_Design/designsets/outcome-label-target-head/Tier-1_000.action_mfe_rer(handmade).outcome.jsonc>), via `tier1_000/datafeeder_input3_outcome1.py`.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
while ROOT.name != "DL-Forecasting" and ROOT.parent != ROOT:
    ROOT = ROOT.parent
APP = ROOT / "app"
if str(APP) not in sys.path:
    sys.path.insert(0, str(APP))

from presentation.dataset_generation.now_review_notebook import (
    SYMBOLS,
    build_review_samples,
    cache_summary,
    plot_now_sample,
    plot_random_period,
    random_cached_period,
)

SYMBOLS
# Out:
# 2026-08-17 14:53:31.732089: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-17 14:53:31.977150: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1786965812.073616   29388 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1786965812.100532   29388 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1786965812.307263   29388 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1786965812.307293   29388 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1786965812.307295   29388 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1786965812.307296   29388 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-08-17 14:53:32.335792: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ['BTCUSDT', 'ETHUSDT', 'AIOUSDT', 'TRXUSDT', 'BNBUSDT']

# %% [markdown]
# ## Local Cache Availability

# %%
cache_summary(SYMBOLS)
# Out:
#     symbol  files                     start                       end  \
# 0  BTCUSDT   1924 2017-12-01 00:00:00+00:00 2025-04-01 23:59:00+00:00
# 1  ETHUSDT    816 2022-06-02 00:00:00+00:00 2024-08-25 23:59:00+00:00
# 2  AIOUSDT      0                       NaT                       NaT
# 3  TRXUSDT    816 2022-06-02 00:00:00+00:00 2024-08-25 23:59:00+00:00
# 4  BNBUSDT    839 2022-06-02 00:00:00+00:00 2024-09-17 23:59:00+00:00
#
#    largest_days
# 0           1.0
# 1           1.0
# 2           NaN
# 3           1.0
# 4           1.0

# %% [markdown]
# Each figure shows one Tier-1_000 model-input sample built by `datafeeder_input3_outcome1.build_dataset()`: one row per branch timeframe (5min/15min/1h/4h/1D/1W), plotting that branch's own `CANDLE_FEATURE_COLUMNS` (ATR-relative OHLC + volume) across its window, with `x=0` marking NOW. The realized `mfe`/`rer`/`action` labels (outcome_set=1) are summarized in each figure's title.

# %%
for symbol in SYMBOLS:
    try:
        samples = build_review_samples(symbol, sample_count=5)
    except Exception as exc:
        print(f"{symbol}: skipped ({exc})")
        continue
    for idx, sample in enumerate(samples, start=1):
        fig = plot_now_sample(sample, title=f"{symbol} NOW sample {idx}")
        fig.show()
# Out:
# 2026-08-17 14:53:36.69 | Level 10 | app.application.model_implementations.tier1_000.datafeeder_input3_outcome1:build_dataset:155 - get_multi_timeframe_ohlcv(17-12-01.00-00T17-12-01.23-59) started (ray:16cdd1a4-9a2e-11f1-9ed8-000000000000)
NaN\n           2017-12-01 16:50:00+00:00   NaN\n           2017-12-01 16:55:00+00:00   NaN\n           2017-12-01 17:25:00+00:00   NaN\n           2017-12-01 17:55:00+00:00   NaN\n           2017-12-01 22:35:00+00:00   NaN\n           2017-12-01 23:25:00+00:00   NaN\n           2017-12-01 23:35:00+00:00   NaN\n           2017-12-01 23:45:00+00:00   NaN\nName: high, dtype: float64"), SchemaError("non-nullable series 'low' contains null values:\ntimeframe  date                     \n5min       2017-12-01 10:20:00+00:00   NaN\n           2017-12-01 14:25:00+00:00   NaN\n15min      2017-12-01 16:00:00+ ...
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/brais/miniconda3/envs/tf/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/brais/miniconda3/envs/tf/lib/python3.12/site-packages/traitlets/config/application.py", line 1080, in launch_instance
#     app.start()
#   File "/home/brais/miniconda3/envs/tf/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 807, in start
#     self.io_loop.start()
#   File "/home/brais/miniconda3/envs/tf/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/home/brais/miniconda3/envs/tf/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#   File "/home/brais/miniconda3/envs/tf/lib/python3.12/asyncio/base_events.py", line 1999, in _run_once
#     handle._run()
#   File "/home/brais/miniconda3/envs/tf/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/brais/miniconda3/envs/tf/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "/home/brais/miniconda3/envs/tf/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "/home/brais/miniconda3/envs/tf/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/brais/miniconda3/envs/tf/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "/home/brais/miniconda3/envs/tf/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 460, in do_execute
#     res = shell.run_cell(
#   File "/home/brais/miniconda3/envs/tf/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 665, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/brais/miniconda3/envs/tf/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3204, in run_cell
#     result = self._run_cell(
#   File "/home/brais/miniconda3/envs/tf/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3261, in _run_cell
#     result = runner(coro)
#   File "/home/brais/miniconda3/envs/tf/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/brais/miniconda3/envs/tf/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3474, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/brais/miniconda3/envs/tf/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3715, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/brais/miniconda3/envs/tf/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3775, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_29388/4223013070.py", line 3, in <module>
#     samples = build_review_samples(symbol, sample_count=5)
#   File "/home/brais/code/DL-Forecasting/app/presentation/dataset_generation/now_review_notebook.py", line 113, in build_review_samples
#     bundle = build_dataset(symbol, date_range_str)
#   File "/home/brais/code/DL-Forecasting/app/application/model_implementations/tier1_000/datafeeder_input3_outcome1.py", line 155, in build_dataset
#     mt_ohlcv = read_multi_timeframe_ohlcv(date_range_str)
#   File "/home/brais/code/DL-Forecasting/app/helper/logging/profiling/base.py", line 22, in _measure_time
#     result = func(*args, **kwargs)
#   File "/home/brais/code/DL-Forecasting/app/infrastructure/disk_cache.py", line 583, in wrapper
#     result = read_file_windowed(
#   File "/home/brais/code/DL-Forecasting/app/infrastructure/disk_cache.py", line 465, in read_file_windowed
#     read_file(
#   File "/home/brais/code/DL-Forecasting/app/infrastructure/disk_cache.py", line 316, in read_file
#     if df is None or not cast_and_validate(df, caster_model, return_bool=True, zero_size_allowed=zero_size_allowed):
#   File "/home/brais/code/DL-Forecasting/app/helper/schema_casting.py", line 59, in cast_and_validate
#     log_d(str(exc.schema_errors), logging.WARNING)
#  (ray:16cdd1a4-9a2e-11f1-9ed8-000000000000)
# 2026-08-17 14:53:36.77 | Level 10 | app.infrastructure.ohlcv.ohlcv:get_multi_timeframe_ohlcv:52 - get_base_timeframe_ohlcv(17-12-01.00-00T17-12-01.23-59) started (ray:16cdd1a4-9a2e-11f1-9ed8-000000000000)
#            2017-12-01 22:35:00+00:00   NaN
#            2017-12-01 23:25:00+00:00   NaN
#            2017-12-01 23:35:00+00:00   NaN
#            2017-12-01 23:45:00+00:00   NaN
# Name: open, dtype: float64)
# 2026-08-17 14:53:36.99 | Level 10 | app.application.model_implementations.tier1_000.datafeeder_input3_outcome1:build_dataset:155 - get_multi_timeframe_ohlcv(22-06-02.00-00T22-06-02.23-59) started (ray:16cdd1a4-9a2e-11f1-9ed8-000000000000)
# 2026-08-17 14:53:37.01 | Level 10 | app.application.model_implementations.tier1_000.datafeeder_input3_outcome1:build_dataset:155 - get_multi_timeframe_ohlcv(22-06-02.00-00T22-06-02.23-59) executed in 0.019 seconds (ray:16cdd1a4-9a2e-11f1-9ed8-000000000000)
# ETHUSDT: skipped ('NoneType' object has no attribute 'rename')
# AIOUSDT: skipped (No local cached multi-timeframe OHLCV found for AIOUSDT)
# 2026-08-17 14:53:37.03 | Level 10 | app.application.model_implementations.tier1_000.datafeeder_input3_outcome1:build_dataset:155 - get_multi_timeframe_ohlcv(22-06-02.00-00T22-06-02.23-59) started (ray:16cdd1a4-9a2e-11f1-9ed8-000000000000)
# 2026-08-17 14:53:37.05 | Level 10 | app.application.model_implementations.tier1_000.datafeeder_input3_outcome1:build_dataset:155 - get_multi_timeframe_ohlcv(22-06-02.00-00T22-06-02.23-59) executed in 0.022 seconds (ray:16cdd1a4-9a2e-11f1-9ed8-000000000000)
# TRXUSDT: skipped ('NoneType' object has no attribute 'rename')
# 2026-08-17 14:53:37.07 | Level 10 | app.application.model_implementations.tier1_000.datafeeder_input3_outcome1:build_dataset:155 - get_multi_timeframe_ohlcv(22-06-02.00-00T22-06-02.23-59) started (ray:16cdd1a4-9a2e-11f1-9ed8-000000000000)
# 2026-08-17 14:53:37.09 | Level 10 | app.application.model_implementations.tier1_000.datafeeder_input3_outcome1:build_dataset:155 - get_multi_timeframe_ohlcv(22-06-02.00-00T22-06-02.23-59) executed in 0.020 seconds (ray:16cdd1a4-9a2e-11f1-9ed8-000000000000)
# BNBUSDT: skipped ('NoneType' object has no attribute 'rename')

# %% [markdown]
# ## Random Two-Week Ranges
#
# Two cached two-week periods are selected per symbol from local files only.

# %%
for symbol in SYMBOLS:
    for chart_no, seed in enumerate([11, 29], start=1):
        try:
            start, end = random_cached_period(symbol, seed=seed)
            fig = plot_random_period(symbol, start, end, chart_no)
        except Exception as exc:
            print(f"{symbol} period chart {chart_no}: skipped ({exc})")
            continue
        fig.show()
# Out:
# BTCUSDT period chart 1: skipped (No local cached 14-day period found for BTCUSDT)
# BTCUSDT period chart 2: skipped (No local cached 14-day period found for BTCUSDT)
# ETHUSDT period chart 1: skipped (No local cached 14-day period found for ETHUSDT)
# ETHUSDT period chart 2: skipped (No local cached 14-day period found for ETHUSDT)
# AIOUSDT period chart 1: skipped (No local cached 14-day period found for AIOUSDT)
# AIOUSDT period chart 2: skipped (No local cached 14-day period found for AIOUSDT)
# TRXUSDT period chart 1: skipped (No local cached 14-day period found for TRXUSDT)
# TRXUSDT period chart 2: skipped (No local cached 14-day period found for TRXUSDT)
# BNBUSDT period chart 1: skipped (No local cached 14-day period found for BNBUSDT)
# BNBUSDT period chart 2: skipped (No local cached 14-day period found for BNBUSDT)
